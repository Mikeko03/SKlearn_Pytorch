# %%
import polars as ps
import matplotlib.pyplot as plt

# %%
train_path = "titanic/train.csv"
test_path = "titanic/test.csv"

# %%
train_df = ps.read_csv(train_path)
y = train_df["Survived"]
train_df = train_df.drop(["Survived"])
train_df
# Out:
# shape: (891, 11)
# ┌─────────────┬────────┬──────────────────┬────────┬─────┬────────────┬─────────┬───────┬──────────┐
# │ PassengerId ┆ Pclass ┆ Name             ┆ Sex    ┆ ... ┆ Ticket     ┆ Fare    ┆ Cabin ┆ Embarked │
# │ ---         ┆ ---    ┆ ---              ┆ ---    ┆     ┆ ---        ┆ ---     ┆ ---   ┆ ---      │
# │ i64         ┆ i64    ┆ str              ┆ str    ┆     ┆ str        ┆ f64     ┆ str   ┆ str      │
# ╞═════════════╪════════╪══════════════════╪════════╪═════╪════════════╪═════════╪═══════╪══════════╡
# │ 1           ┆ 3      ┆ Braund, Mr. Owen ┆ male   ┆ ... ┆ A/5 21171  ┆ 7.25    ┆ null  ┆ S        │
# │             ┆        ┆ Harris           ┆        ┆     ┆            ┆         ┆       ┆          │
# │ 2           ┆ 1      ┆ Cumings, Mrs.    ┆ female ┆ ... ┆ PC 17599   ┆ 71.2833 ┆ C85   ┆ C        │
# │             ┆        ┆ John Bradley     ┆        ┆     ┆            ┆         ┆       ┆          │
# ...

# %%
## fill na in age, but first look what are the most common in the missing age, (fare, etc...)
## select - len jeden stlpec
## filter vsetky stplce


train_df.null_count()
# Out:
# shape: (1, 11)
# ┌─────────────┬────────┬──────┬─────┬─────┬────────┬──────┬───────┬──────────┐
# │ PassengerId ┆ Pclass ┆ Name ┆ Sex ┆ ... ┆ Ticket ┆ Fare ┆ Cabin ┆ Embarked │
# │ ---         ┆ ---    ┆ ---  ┆ --- ┆     ┆ ---    ┆ ---  ┆ ---   ┆ ---      │
# │ u32         ┆ u32    ┆ u32  ┆ u32 ┆     ┆ u32    ┆ u32  ┆ u32   ┆ u32      │
# ╞═════════════╪════════╪══════╪═════╪═════╪════════╪══════╪═══════╪══════════╡
# │ 0           ┆ 0      ┆ 0    ┆ 0   ┆ ... ┆ 0      ┆ 0    ┆ 687   ┆ 2        │
# └─────────────┴────────┴──────┴─────┴─────┴────────┴──────┴───────┴──────────┘

# %%
train_df.filter(
    ps.col("Age").is_null(),)
# Out:
# shape: (177, 11)
# ┌─────────────┬────────┬───────────────────┬────────┬─────┬────────────┬────────┬───────┬──────────┐
# │ PassengerId ┆ Pclass ┆ Name              ┆ Sex    ┆ ... ┆ Ticket     ┆ Fare   ┆ Cabin ┆ Embarked │
# │ ---         ┆ ---    ┆ ---               ┆ ---    ┆     ┆ ---        ┆ ---    ┆ ---   ┆ ---      │
# │ i64         ┆ i64    ┆ str               ┆ str    ┆     ┆ str        ┆ f64    ┆ str   ┆ str      │
# ╞═════════════╪════════╪═══════════════════╪════════╪═════╪════════════╪════════╪═══════╪══════════╡
# │ 6           ┆ 3      ┆ Moran, Mr. James  ┆ male   ┆ ... ┆ 330877     ┆ 8.4583 ┆ null  ┆ Q        │
# │ 18          ┆ 2      ┆ Williams, Mr.     ┆ male   ┆ ... ┆ 244373     ┆ 13.0   ┆ null  ┆ S        │
# │             ┆        ┆ Charles Eugene    ┆        ┆     ┆            ┆        ┆       ┆          │
# │ 20          ┆ 3      ┆ Masselmani, Mrs.  ┆ female ┆ ... ┆ 2649       ┆ 7.225  ┆ null  ┆ C        │
# ...

# %%
train_df = train_df.with_column(ps.col("Age").fill_null(ps.median("Age")))
train_df
# Out:
# shape: (891, 11)
# ┌─────────────┬────────┬──────────────────┬────────┬─────┬────────────┬─────────┬───────┬──────────┐
# │ PassengerId ┆ Pclass ┆ Name             ┆ Sex    ┆ ... ┆ Ticket     ┆ Fare    ┆ Cabin ┆ Embarked │
# │ ---         ┆ ---    ┆ ---              ┆ ---    ┆     ┆ ---        ┆ ---     ┆ ---   ┆ ---      │
# │ i64         ┆ i64    ┆ str              ┆ str    ┆     ┆ str        ┆ f64     ┆ str   ┆ str      │
# ╞═════════════╪════════╪══════════════════╪════════╪═════╪════════════╪═════════╪═══════╪══════════╡
# │ 1           ┆ 3      ┆ Braund, Mr. Owen ┆ male   ┆ ... ┆ A/5 21171  ┆ 7.25    ┆ null  ┆ S        │
# │             ┆        ┆ Harris           ┆        ┆     ┆            ┆         ┆       ┆          │
# │ 2           ┆ 1      ┆ Cumings, Mrs.    ┆ female ┆ ... ┆ PC 17599   ┆ 71.2833 ┆ C85   ┆ C        │
# │             ┆        ┆ John Bradley     ┆        ┆     ┆            ┆         ┆       ┆          │
# ...

# %%
train_df.null_count()
# Out:
# shape: (1, 11)
# ┌─────────────┬────────┬──────┬─────┬─────┬────────┬──────┬───────┬──────────┐
# │ PassengerId ┆ Pclass ┆ Name ┆ Sex ┆ ... ┆ Ticket ┆ Fare ┆ Cabin ┆ Embarked │
# │ ---         ┆ ---    ┆ ---  ┆ --- ┆     ┆ ---    ┆ ---  ┆ ---   ┆ ---      │
# │ u32         ┆ u32    ┆ u32  ┆ u32 ┆     ┆ u32    ┆ u32  ┆ u32   ┆ u32      │
# ╞═════════════╪════════╪══════╪═════╪═════╪════════╪══════╪═══════╪══════════╡
# │ 0           ┆ 0      ┆ 0    ┆ 0   ┆ ... ┆ 0      ┆ 0    ┆ 687   ┆ 2        │
# └─────────────┴────────┴──────┴─────┴─────┴────────┴──────┴───────┴──────────┘

# %%
train_df.filter(ps.col("Cabin").is_null())["Embarked"].value_counts()
# Out:
# shape: (3, 2)
# ┌──────────┬────────┐
# │ Embarked ┆ counts │
# │ ---      ┆ ---    │
# │ str      ┆ u32    │
# ╞══════════╪════════╡
# │ Q        ┆ 73     │
# │ S        ┆ 515    │
# │ C        ┆ 99     │
# └──────────┴────────┘
